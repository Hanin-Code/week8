# %% [markdown]
# # Continuous Bag of Words (CBOW) Model

# %% [markdown]
# In this exam, we will create a CBOW model using a sample Arabic traffic corpus. The corpus consists of sentences describing various traffic scenarios. The goal of the CBOW model is to predict a target word based on its surrounding context words.

# %% [markdown]
# # Importing Required Libraries

# %% [markdown]
# In this step, we import the necessary libraries to build and train the Continuous Bag of Words (CBOW) model.
#
# - **TensorFlow and Keras**: Used to build the neural network model, including the layers like `Embedding`, `Dense`, and `Lambda`.
# - **Tokenizer**: A utility from Keras for tokenizing and processing text data.
# - **NumPy**: Used for handling numerical operations, particularly for processing arrays and data manipulation.
#
# These libraries will provide the essential tools for text preprocessing and model development in the upcoming steps.
#
# Add more if needed!

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Input, Bidirectional, SimpleRNN, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Lambda, Dropout
from tensorflow.keras.preprocessing import sequence
from collections import Counter

# %% [markdown]
# # Preparing the Corpus

# %% [markdown]
# In this step, we initialize the corpus that will be used for training the Continuous Bag of Words (CBOW) model. The corpus consists of Arabic sentences, each of which describes different traffic scenarios.
#
# - **Corpus**: A collection of traffic-related sentences in Arabic.
#
# This step sets up the text data that we will use in the upcoming stages of tokenization and model training.

# %%
corpus = [
    "الطريق مزدحم اليوم بسبب الحادث المروري الذي حدث صباحاً ويؤدي إلى تأخير كبير في الوصول",
    "كان الطريق مزدحما للغاية والسيارات متوقفة تقريباً نتيجة الازدحام الشديد والحركة بطيئة جداً ولا تتحسن",
    "أنا أحب الذهاب إلى السوق في الصباح الباكر لتفادي الازدحام وشراء الخضروات الطازجة دون الانتظار في الطريق",
    "السيارات بطيئة بسبب الازدحام المروري في الشارع الرئيسي والتأخير في حركة المرور خلال ساعات الذروة",
    "هناك ازدحام مروري في الشارع بسبب أعمال البناء والحفريات التي تعطل حركة السيارات وتتسبب في تأخير كبير",
    "ازدحام السيارات يزداد في المساء عندما يبدأ الجميع بالعودة إلى منازلهم من العمل وتتوقف حركة المرور بالكامل",
    "الطريق السريع يشهد ازدحاما مستمرا خلال فترة الظهيرة بسبب الشاحنات الكبيرة التي تبطئ حركة السير",
    "الحافلات والسيارات عالقة في الازدحام المروري في المنطقة التجارية مما يؤدي إلى تأخير وصول الناس إلى وجهاتهم",
    "حركة المرور مزدحمة اليوم بسبب الفعاليات التي تقام في وسط المدينة مما يزيد من صعوبة الوصول إلى هناك",
    "كان من الصعب جدا القيادة على الطريق الرئيسي اليوم بسبب الازدحام الخانق الذي استمر طوال اليوم",
    "الطريق إلى المطار مزدحم اليوم بسبب الحوادث المتكررة والتأخيرات الكبيرة في حركة المرور على الطريق السريع",
    "الشارع مزدحم بالسيارات والحافلات الكبيرة مما يجعل التنقل بطيئًا جدًا ويزيد من وقت الوصول إلى العمل",
    "ازدحام السيارات في المدينة أصبح مشكلة كبيرة خاصة خلال ساعات الذروة حيث يصعب التحرك بسرعة",
    "تفاقم الازدحام في الطرق الجانبية بسبب إغلاق الطريق الرئيسي المؤدي إلى وسط المدينة لصيانة الجسر",
    "ازدحام مروري خانق يواجه السكان يوميًا خلال تنقلهم من وإلى العمل على الطرق السريعة المؤدية إلى المدينة",
    "التأخيرات المرورية اليوم ناجمة عن سوء الأحوال الجوية والضباب الذي يعيق الرؤية ويبطئ حركة السيارات",
    "حوادث السير المتكررة على الطريق الزراعي تؤدي إلى ازدحام مروري شديد وتأخير كبير في وصول السيارات",
    "كانت حركة السير اليوم غير منتظمة بسبب تنظيم حدث رياضي كبير أدى إلى إغلاق بعض الشوارع الرئيسية",
    "الأعمال الإنشائية في الشارع الرئيسي تسببت في اختناق مروري كامل وتباطؤ في حركة السيارات خلال النهار",
    "تراكم السيارات عند تقاطع الطرق الرئيسية أدى إلى ازدحام شديد وزيادة كبيرة في مدة الانتظار للوصول إلى الجهة المطلوبة"
]

# %% [markdown]
# # Defining Vocabulary and Model Parameters

# %% [markdown]
# In this step, we define key parameters that will be used to configure the CBOW model.
#
# - **Vocabulary size**: We calculate the size of the vocabulary based on the number of unique words in the corpus. The `vocab_size` represents the total number of unique tokens (words) in the dataset plus one for padding.
#
# - **Embedding size**: The `embedding_size` defines the dimensionality of the word embeddings. In this case, we set the embedding size to 10, meaning each word will be represented as a 10-dimensional vector in the embedding layer.
#
# - **Window size**: The `window_size` defines how many words to the left and right of the target word are considered as context. Here, a window size of 2 means that two words before and two words after the target word will be used as context.
#
# These parameters will play an essential role in shaping the CBOW model architecture.

# %%
(len(Counter(" ". join(corpus).split())))
# Out:
# 178

# %%
vocab_size=(len(Counter(" ". join(corpus).split())))+1
embedding_size=10
window_size=2

# %%
vocab_size
# Out:
# 179

# %% [markdown]
# # Preparing Context-Target Pairs for CBOW

# %% [markdown]
# In this step, we generate the context-target pairs from the tokenized sequences to train the CBOW model.
#
# - **Context words**: For each word in a sequence, the surrounding words (within the window size) are considered as context. The context consists of the words immediately before and after the target word.
#
# - **Target word**: The word in the middle of the context window is treated as the target word that the model will learn to predict.
#
# We iterate through each sequence, collecting the context words and corresponding target words:
# - For each word in a sequence, we gather the surrounding words based on the defined window size.
# - The middle word is the target, and the surrounding words form the context.
#
# Finally:
# - **`X`**: An array of context words.
# - **`y`**: The target words are one-hot encoded, which means they are converted into a categorical format where each word is represented as a vector of length equal to the vocabulary size.
#
# These context-target pairs will be used to train the CBOW model to predict a target word based on its context.

# %%
toknizer = Tokenizer()
toknizer.fit_on_texts(corpus)
sequences = toknizer.texts_to_sequences(corpus)

# %%
sequences[0]
# Out:
# [3, 19, 7, 4, 47, 20, 21, 30, 48, 49, 2, 22, 12, 1, 23]

# %%
contexts= []
targets = []

for sequence in sequences:
    for i in range(window_size, len(sequence) - window_size):
        context= sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
        target= sequence[i]
        contexts.append(context)
        targets.append(target)

X= np.array(contexts)
y= tf.keras.utils.to_categorical(targets, num_classes=vocab_size)

# %%
X[0]
# Out:
# array([ 3, 19,  4, 47])

# %% [markdown]
# # Building and Training the CBOW Model

# %% [markdown]
# In this step, we build and train the Continuous Bag of Words (CBOW) model using the context-target pairs created earlier.
#
# 1. **Model architecture**:
#    - **Embedding layer**: This layer transforms the input context words into dense vector representations (embeddings) of size defined by `embedding_size`. The `input_dim` is set to the vocabulary size, and the `input_length` is twice the window size (since context consists of words from both sides of the target).
#
#    - **Lambda layer**: This layer computes the mean of the context word embeddings. It averages the embeddings of the context words to generate a single representation that will be used to predict the target word.
#
#    - **Dense layer**: This fully connected layer outputs a probability distribution over the vocabulary, using the softmax activation function. It predicts the most likely target word based on the context word embeddings.
#
# 2. **Compilation**:
#    The model is compiled using the Adam optimizer and categorical cross-entropy as the loss function, which is suitable for multi-class classification tasks. Accuracy is used as a metric to evaluate the model's performance during training.
#
# 3. **Training the model**:
#    The model is trained on the context-target pairs for 500 epochs. During each epoch, the model learns to predict the target word based on the context, refining its weights to improve accuracy.
#
# 4. **Saving the model weights**:
#    After training, the model weights are saved to a file (`cbow_model.weights.h5`) for future use. This allows us to load the trained model later without retraining.
#
# By the end of this step, the CBOW model will have learned to predict target words based on their surrounding context from the given corpus.

# %%
model =Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2*window_size))
model.add(Lambda(lambda x:tf.reduce_mean(x, axis=1)))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=vocab_size, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) #Compilation

model.fit(X, y, epochs=500, verbose=1) #Training the model
model.save_weights('cbow_model.weights.h5') #Saving the model weights
# Out:
# Epoch 1/500
# 8/8 [==============================] - 1s 7ms/step - loss: 5.1865 - accuracy: 0.0287
# Epoch 2/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.1788 - accuracy: 0.0615
# Epoch 3/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.1703 - accuracy: 0.0697
# Epoch 4/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.1591 - accuracy: 0.0697
# Epoch 5/500
# 8/8 [==============================] - 0s 3ms/step - loss: 5.1441 - accuracy: 0.0697
# Epoch 6/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.1236 - accuracy: 0.0697
# Epoch 7/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.0959 - accuracy: 0.0697
# Epoch 8/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.0605 - accuracy: 0.0697
# Epoch 9/500
# 8/8 [==============================] - 0s 4ms/step - loss: 5.0156 - accuracy: 0.0697
# Epoch 10/500
# 8/8 [==============================] - 0s 4ms/step - loss: 4.9679 - accuracy: 0.0697
# Epoch 11/500
# 8/8 [==============================] - 0s 3ms/step - loss: 4.9053 - accuracy: 0.0697
# Epoch 12/500
# 8/8 [==============================] - 0s 3ms/step - loss: 4.8463 - accuracy: 0.0697
# Epoch 13/500
# 8/8 [==============================] - 0s 3ms/step - loss: 4.7805 - accuracy: 0.0697
# Epoch 14/500
# 8/8 [==============================] - 0s 3ms/step - loss: 4.7150 - accuracy: 0.0697
# Epoch 15/500
# 8/8 [==============================] - 0s 4ms/step - loss: 4.6534 - accuracy: 0.0697
# Epoch 16/500
# 8/8 [==============================] - 0s 4ms/step - loss: 4.6070 - accuracy: 0.0697
# Epoch 17/500
# 8/8 [==============================] - 0s 4ms/step - loss: 4.5671 - accuracy: 0.0697
# Epoch 18/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.5313 - accuracy: 0.0697
# Epoch 19/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.5002 - accuracy: 0.0697
# Epoch 20/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.4678 - accuracy: 0.0697
# Epoch 21/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.4310 - accuracy: 0.0697
# Epoch 22/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.3904 - accuracy: 0.0697
# Epoch 23/500
# 8/8 [==============================] - 0s 6ms/step - loss: 4.3412 - accuracy: 0.0697
# Epoch 24/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.3094 - accuracy: 0.0697
# Epoch 25/500
# 8/8 [==============================] - 0s 6ms/step - loss: 4.2669 - accuracy: 0.0697
# Epoch 26/500
# 8/8 [==============================] - 0s 4ms/step - loss: 4.2173 - accuracy: 0.0697
# Epoch 27/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.1803 - accuracy: 0.0656
# Epoch 28/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.1262 - accuracy: 0.0779
# Epoch 29/500
# 8/8 [==============================] - 0s 6ms/step - loss: 4.0858 - accuracy: 0.0861
# Epoch 30/500
# 8/8 [==============================] - 0s 5ms/step - loss: 4.0322 - accuracy: 0.0861
# Epoch 31/500
# 8/8 [==============================] - 0s 5ms/step - loss: 3.9882 - accuracy: 0.0943
# Epoch 32/500
# 8/8 [==============================] - 0s 3ms/step - loss: 3.9343 - accuracy: 0.0943
# Epoch 33/500
# 8/8 [==============================] - 0s 4ms/step - loss: 3.8883 - accuracy: 0.1025
# Epoch 34/500
# 8/8 [==============================] - 0s 3ms/step - loss: 3.8352 - accuracy: 0.1025
# Epoch 35/500
# 8/8 [==============================] - 0s 3ms/step - loss: 3.7826 - accuracy: 0.1066
# Epoch 36/500
# 8/8 [==============================] - 0s 4ms/step - loss: 3.7436 - accuracy: 0.0984
# Epoch 37/500
# 8/8 [==============================] - 0s 4ms/step - loss: 3.6922 - accuracy: 0.1025
# Epoch 38/500
# 8/8 [==============================] - 0s 4ms/step - loss: 3.6424 - accuracy: 0.1189
# Epoch 39/500
# 8/8 [==============================] - 0s 4ms/step - loss: 3.6029 - accuracy: 0.1189
# Epoch 40/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.5487 - accuracy: 0.1025
# Epoch 41/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.4907 - accuracy: 0.1311
# Epoch 42/500
# 8/8 [==============================] - 0s 8ms/step - loss: 3.4435 - accuracy: 0.1352
# Epoch 43/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.3981 - accuracy: 0.1639
# Epoch 44/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.3452 - accuracy: 0.1639
# Epoch 45/500
# 8/8 [==============================] - 0s 7ms/step - loss: 3.2942 - accuracy: 0.1721
# Epoch 46/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.2356 - accuracy: 0.1721
# Epoch 47/500
# 8/8 [==============================] - 0s 5ms/step - loss: 3.1853 - accuracy: 0.1639
# Epoch 48/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.1246 - accuracy: 0.2049
# Epoch 49/500
# 8/8 [==============================] - 0s 6ms/step - loss: 3.0790 - accuracy: 0.1926
# Epoch 50/500
# 8/8 [==============================] - 0s 5ms/step - loss: 3.0403 - accuracy: 0.2131
# Epoch 51/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.9704 - accuracy: 0.2295
# Epoch 52/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.9123 - accuracy: 0.2377
# Epoch 53/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.8806 - accuracy: 0.2377
# Epoch 54/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.8341 - accuracy: 0.2459
# Epoch 55/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.7726 - accuracy: 0.2705
# Epoch 56/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.7057 - accuracy: 0.2992
# Epoch 57/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.6787 - accuracy: 0.2992
# Epoch 58/500
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5935 - accuracy: 0.3033
# Epoch 59/500
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5201 - accuracy: 0.3607
# Epoch 60/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.5086 - accuracy: 0.3525
# Epoch 61/500
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4707 - accuracy: 0.3893
# Epoch 62/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.3796 - accuracy: 0.4139
# Epoch 63/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.3309 - accuracy: 0.4344
# Epoch 64/500
# 8/8 [==============================] - 0s 6ms/step - loss: 2.2920 - accuracy: 0.4344
# Epoch 65/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.2320 - accuracy: 0.4959
# Epoch 66/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.1896 - accuracy: 0.5000
# Epoch 67/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.1450 - accuracy: 0.4877
# Epoch 68/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.0686 - accuracy: 0.4836
# Epoch 69/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.0528 - accuracy: 0.5246
# Epoch 70/500
# 8/8 [==============================] - 0s 5ms/step - loss: 2.0190 - accuracy: 0.5205
# Epoch 71/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.9623 - accuracy: 0.5697
# Epoch 72/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.9282 - accuracy: 0.5615
# Epoch 73/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.8559 - accuracy: 0.5861
# Epoch 74/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.8172 - accuracy: 0.6025
# Epoch 75/500
# 8/8 [==============================] - 0s 7ms/step - loss: 1.7821 - accuracy: 0.6189
# Epoch 76/500
# 8/8 [==============================] - 0s 8ms/step - loss: 1.7604 - accuracy: 0.6189
# Epoch 77/500
# 8/8 [==============================] - 0s 7ms/step - loss: 1.6674 - accuracy: 0.6434
# Epoch 78/500
# 8/8 [==============================] - 0s 7ms/step - loss: 1.6067 - accuracy: 0.6639
# Epoch 79/500
# 8/8 [==============================] - 0s 7ms/step - loss: 1.6089 - accuracy: 0.7008
# Epoch 80/500
# 8/8 [==============================] - 0s 7ms/step - loss: 1.5707 - accuracy: 0.6639
# Epoch 81/500
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4985 - accuracy: 0.7172
# Epoch 82/500
# 8/8 [==============================] - 0s 9ms/step - loss: 1.5057 - accuracy: 0.6926
# Epoch 83/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.4575 - accuracy: 0.7008
# Epoch 84/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.4066 - accuracy: 0.7213
# Epoch 85/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.4064 - accuracy: 0.7049
# Epoch 86/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.3646 - accuracy: 0.7336
# Epoch 87/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.2980 - accuracy: 0.7869
# Epoch 88/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.2986 - accuracy: 0.7623
# Epoch 89/500
# 8/8 [==============================] - 0s 9ms/step - loss: 1.2509 - accuracy: 0.7828
# Epoch 90/500
# 8/8 [==============================] - 0s 12ms/step - loss: 1.2531 - accuracy: 0.7828
# Epoch 91/500
# 8/8 [==============================] - 0s 8ms/step - loss: 1.1998 - accuracy: 0.8115
# Epoch 92/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.1694 - accuracy: 0.7910
# Epoch 93/500
# 8/8 [==============================] - 0s 7ms/step - loss: 1.1379 - accuracy: 0.7910
# Epoch 94/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0794 - accuracy: 0.8156
# Epoch 95/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0864 - accuracy: 0.8156
# Epoch 96/500
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0343 - accuracy: 0.7869
# Epoch 97/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0248 - accuracy: 0.8361
# Epoch 98/500
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0230 - accuracy: 0.7992
# Epoch 99/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9506 - accuracy: 0.8566
# Epoch 100/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9281 - accuracy: 0.8484
# Epoch 101/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9365 - accuracy: 0.8443
# Epoch 102/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8962 - accuracy: 0.8648
# Epoch 103/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8953 - accuracy: 0.8648
# Epoch 104/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8641 - accuracy: 0.8566
# Epoch 105/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8266 - accuracy: 0.8934
# Epoch 106/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8032 - accuracy: 0.9016
# Epoch 107/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8237 - accuracy: 0.8770
# Epoch 108/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8105 - accuracy: 0.8689
# Epoch 109/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7535 - accuracy: 0.8934
# Epoch 110/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7334 - accuracy: 0.9303
# Epoch 111/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7409 - accuracy: 0.9057
# Epoch 112/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7214 - accuracy: 0.8975
# Epoch 113/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7130 - accuracy: 0.9262
# Epoch 114/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6655 - accuracy: 0.9467
# Epoch 115/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6321 - accuracy: 0.9180
# Epoch 116/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6322 - accuracy: 0.9221
# Epoch 117/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6294 - accuracy: 0.9180
# Epoch 118/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6397 - accuracy: 0.9262
# Epoch 119/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5769 - accuracy: 0.9385
# Epoch 120/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5892 - accuracy: 0.9303
# Epoch 121/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5881 - accuracy: 0.9139
# Epoch 122/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5600 - accuracy: 0.9262
# Epoch 123/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5383 - accuracy: 0.9467
# Epoch 124/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4954 - accuracy: 0.9549
# Epoch 125/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5438 - accuracy: 0.9303
# Epoch 126/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5206 - accuracy: 0.9590
# Epoch 127/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.9426
# Epoch 128/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5034 - accuracy: 0.9672
# Epoch 129/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4775 - accuracy: 0.9549
# Epoch 130/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4841 - accuracy: 0.9590
# Epoch 131/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4507 - accuracy: 0.9590
# Epoch 132/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4513 - accuracy: 0.9549
# Epoch 133/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4264 - accuracy: 0.9631
# Epoch 134/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.9549
# Epoch 135/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.9590
# Epoch 136/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4213 - accuracy: 0.9631
# Epoch 137/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3964 - accuracy: 0.9672
# Epoch 138/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3931 - accuracy: 0.9590
# Epoch 139/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3976 - accuracy: 0.9672
# Epoch 140/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3866 - accuracy: 0.9631
# Epoch 141/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3737 - accuracy: 0.9713
# Epoch 142/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3530 - accuracy: 0.9795
# Epoch 143/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3431 - accuracy: 0.9672
# Epoch 144/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3551 - accuracy: 0.9631
# Epoch 145/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3207 - accuracy: 0.9713
# Epoch 146/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.9836
# Epoch 147/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3212 - accuracy: 0.9631
# Epoch 148/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3270 - accuracy: 0.9549
# Epoch 149/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3079 - accuracy: 0.9836
# Epoch 150/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3036 - accuracy: 0.9877
# Epoch 151/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2987 - accuracy: 0.9795
# Epoch 152/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2689 - accuracy: 0.9672
# Epoch 153/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2818 - accuracy: 0.9877
# Epoch 154/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2784 - accuracy: 0.9754
# Epoch 155/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2623 - accuracy: 0.9754
# Epoch 156/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2687 - accuracy: 0.9754
# Epoch 157/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2740 - accuracy: 0.9795
# Epoch 158/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2894 - accuracy: 0.9754
# Epoch 159/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2583 - accuracy: 0.9672
# Epoch 160/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2635 - accuracy: 0.9836
# Epoch 161/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.9713
# Epoch 162/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2423 - accuracy: 0.9836
# Epoch 163/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2113 - accuracy: 0.9877
# Epoch 164/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2639 - accuracy: 0.9877
# Epoch 165/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2330 - accuracy: 0.9877
# Epoch 166/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2222 - accuracy: 0.9713
# Epoch 167/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2391 - accuracy: 0.9713
# Epoch 168/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2296 - accuracy: 0.9877
# Epoch 169/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2130 - accuracy: 0.9918
# Epoch 170/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2195 - accuracy: 0.9836
# Epoch 171/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1887 - accuracy: 0.9918
# Epoch 172/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2119 - accuracy: 0.9877
# Epoch 173/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2021 - accuracy: 0.9795
# Epoch 174/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.9836
# Epoch 175/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1885 - accuracy: 0.9877
# Epoch 176/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2017 - accuracy: 0.9918
# Epoch 177/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1914 - accuracy: 0.9959
# Epoch 178/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1768 - accuracy: 0.9918
# Epoch 179/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1805 - accuracy: 0.9918
# Epoch 180/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1791 - accuracy: 0.9877
# Epoch 181/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1689 - accuracy: 0.9877
# Epoch 182/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1584 - accuracy: 0.9918
# Epoch 183/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1647 - accuracy: 0.9877
# Epoch 184/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1570 - accuracy: 0.9877
# Epoch 185/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1769 - accuracy: 0.9918
# Epoch 186/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1506 - accuracy: 1.0000
# Epoch 187/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1447 - accuracy: 0.9959
# Epoch 188/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 1.0000
# Epoch 189/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1571 - accuracy: 0.9877
# Epoch 190/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1419 - accuracy: 1.0000
# Epoch 191/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1588 - accuracy: 0.9918
# Epoch 192/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1455 - accuracy: 0.9877
# Epoch 193/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1441 - accuracy: 0.9918
# Epoch 194/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1274 - accuracy: 0.9959
# Epoch 195/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1348 - accuracy: 0.9918
# Epoch 196/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1365 - accuracy: 0.9877
# Epoch 197/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1425 - accuracy: 0.9918
# Epoch 198/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1140 - accuracy: 1.0000
# Epoch 199/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1234 - accuracy: 0.9959
# Epoch 200/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1306 - accuracy: 0.9877
# Epoch 201/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1157 - accuracy: 0.9918
# Epoch 202/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1178 - accuracy: 1.0000
# Epoch 203/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1162 - accuracy: 0.9918
# Epoch 204/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.9918
# Epoch 205/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1141 - accuracy: 0.9918
# Epoch 206/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.9877
# Epoch 207/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1125 - accuracy: 1.0000
# Epoch 208/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1146 - accuracy: 0.9918
# Epoch 209/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1046 - accuracy: 1.0000
# Epoch 210/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1116 - accuracy: 1.0000
# Epoch 211/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1075 - accuracy: 0.9959
# Epoch 212/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0980 - accuracy: 0.9959
# Epoch 213/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 1.0000
# Epoch 214/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9959
# Epoch 215/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1030 - accuracy: 0.9959
# Epoch 216/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1015 - accuracy: 1.0000
# Epoch 217/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0897 - accuracy: 1.0000
# Epoch 218/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0952 - accuracy: 1.0000
# Epoch 219/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1009 - accuracy: 0.9877
# Epoch 220/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 0.9918
# Epoch 221/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 1.0000
# Epoch 222/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 1.0000
# Epoch 223/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0936 - accuracy: 1.0000
# Epoch 224/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0873 - accuracy: 1.0000
# Epoch 225/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 1.0000
# Epoch 226/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 0.9959
# Epoch 227/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0842 - accuracy: 1.0000
# Epoch 228/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0889 - accuracy: 0.9959
# Epoch 229/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 230/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0910 - accuracy: 0.9959
# Epoch 231/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0698 - accuracy: 1.0000
# Epoch 232/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9959
# Epoch 233/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0808 - accuracy: 0.9959
# Epoch 234/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0766 - accuracy: 1.0000
# Epoch 235/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9959
# Epoch 236/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 237/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.9959
# Epoch 238/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0699 - accuracy: 0.9959
# Epoch 239/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 1.0000
# Epoch 240/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9959
# Epoch 241/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 0.9959
# Epoch 242/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0843 - accuracy: 1.0000
# Epoch 243/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0701 - accuracy: 0.9959
# Epoch 244/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9918
# Epoch 245/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0694 - accuracy: 1.0000
# Epoch 246/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0714 - accuracy: 1.0000
# Epoch 247/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0614 - accuracy: 1.0000
# Epoch 248/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 1.0000
# Epoch 249/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 250/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 251/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0689 - accuracy: 0.9918
# Epoch 252/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 253/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0627 - accuracy: 0.9959
# Epoch 254/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 255/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9959
# Epoch 256/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0672 - accuracy: 0.9959
# Epoch 257/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 1.0000
# Epoch 258/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0625 - accuracy: 1.0000
# Epoch 259/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 260/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 261/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 0.9959
# Epoch 262/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 263/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 264/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 265/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 266/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 267/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 268/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 269/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9959
# Epoch 270/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 271/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 272/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 273/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0445 - accuracy: 1.0000
# Epoch 274/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 275/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 276/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 277/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0498 - accuracy: 0.9959
# Epoch 278/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9959
# Epoch 279/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 280/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 281/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 282/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 283/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 284/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 285/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 286/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 287/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0458 - accuracy: 1.0000
# Epoch 288/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 289/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 290/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9959
# Epoch 291/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 292/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 293/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 294/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 295/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 296/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 297/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0431 - accuracy: 0.9959
# Epoch 298/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 299/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 0.9959
# Epoch 300/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9959
# Epoch 301/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 302/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 0.9959
# Epoch 303/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 304/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 305/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 306/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0486 - accuracy: 0.9959
# Epoch 307/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 308/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 309/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 310/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 311/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 312/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 313/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 314/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 315/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 316/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 317/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 318/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 319/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 320/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 321/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 322/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 323/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 324/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 325/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 326/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 327/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0316 - accuracy: 0.9959
# Epoch 328/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 329/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 330/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9959
# Epoch 331/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 332/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 333/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 334/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 335/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 336/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 337/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 338/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 339/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 340/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 341/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 342/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 343/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 344/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 345/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 346/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 347/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 348/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 349/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 350/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 351/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 352/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 353/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 354/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 355/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 356/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 0.9959
# Epoch 357/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 358/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 359/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 360/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 361/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 362/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 363/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 364/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 365/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 366/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 367/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 368/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 369/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0193 - accuracy: 0.9959
# Epoch 370/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 371/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 372/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 373/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 374/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 375/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 376/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9959
# Epoch 377/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 378/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 379/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 380/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 381/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9959
# Epoch 382/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 383/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 384/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 385/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 386/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 387/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 388/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 389/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 390/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 391/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 392/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 393/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 394/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 395/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 396/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 397/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 398/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 399/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 400/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0244 - accuracy: 0.9959
# Epoch 401/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 402/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 403/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 404/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 405/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 406/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 407/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 408/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 409/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 410/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 411/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 412/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 413/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 414/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 415/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0176 - accuracy: 0.9959
# Epoch 416/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 417/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 418/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 419/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 420/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 421/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 422/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 423/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 424/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 425/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 426/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 427/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 428/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 429/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 430/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 431/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 432/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 433/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 434/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 435/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 436/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 437/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 438/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 439/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 440/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 441/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 442/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 443/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 444/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 445/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9959
# Epoch 446/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 447/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 448/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 449/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 450/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 451/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9959
# Epoch 452/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 453/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 454/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 455/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 456/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 457/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 458/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 459/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 460/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 461/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 462/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 463/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 464/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 465/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 466/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 467/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 468/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 469/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 470/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 471/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 472/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 473/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 474/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 475/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 476/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 477/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 478/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 479/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 480/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 481/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 482/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 483/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 484/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 485/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 486/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 487/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 488/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 489/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 490/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 491/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 492/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 493/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 494/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 495/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 496/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 497/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 498/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 499/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 500/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000

# %% [markdown]
# # Predicting a Word Using the Trained CBOW Model

# %% [markdown]
# In this step, we define a function to predict a word based on a given context using the trained CBOW model.
#
# 1. **Function: `predict_word`**:
#    - **Input**: The function takes a list of context words as input. The number of context words should match the expected size (2 times the window size).
#    - **Context sequence conversion**: The input context words are tokenized into a sequence of integers using the same tokenizer that was used during training.
#    - **Input validation**: The function checks whether the length of the context sequence matches the expected size (2 times the window size). If not, it prints an error message.
#    - **Prediction**: The tokenized context is fed into the trained CBOW model, which predicts the probability distribution over the vocabulary.
#    - **Retrieve predicted word**: The predicted word is the one with the highest probability. The function retrieves the word corresponding to the predicted index from the tokenizer's word index.
#
# 2. **Example**:
#    - We provide a sample context: `['الحادث', 'بسبب', 'مزدحم', 'الطريق']`.
#    - The function predicts the word that fits best in this context, based on the model's learned weights.
#    - The predicted word is printed along with the input context.
#
# This function allows us to test the CBOW model by predicting words based on their surrounding context from the corpus.

# %%
def predict_word(context_words, cbow_model, tokenizer, window_size, vocab_size):
    context_indices = [tokenizer.word_index[word] for word in context_words if word in tokenizer.word_index]
    context_vector = np.array(context_indices).reshape(1, -1)
    prediction = cbow_model.predict(context_vector)
    predicted_index = np.argmax(prediction)
    predicted_word = tokenizer.index_word[predicted_index]
    print(f"Context: {' '.join(context_words)}->Predicted word: {predicted_word}")

example_1 = [' الطريق مزدحم بسبب الحادث']
context1 = example_1[0].split()
predict_word(context1, model, tokenizer, window_size, vocab_size)

example_2 = [' كانت نتيجة الحادث تشير']
context2 = example_2[0].split()
predict_word(context2, model, tokenizer, window_size, vocab_size)

example_3 = ['الطريق يحتاج ']
context3 = example_3[0].split()
predict_word(context3, model, tokenizer, window_size, vocab_size)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Context: الطريق مزدحم بسبب الحادث->Predicted word: اليوم
# 1/1 [==============================] - 0s 74ms/step
# Context: كانت نتيجة الحادث تشير->Predicted word: الخانق
# 1/1 [==============================] - 0s 23ms/step
# Context: الطريق يحتاج->Predicted word: القيادة
